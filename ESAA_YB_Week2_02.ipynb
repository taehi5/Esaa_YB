# %% [markdown]
# <a href="https://colab.research.google.com/github/taehi5/Esaa_YB/blob/2%EC%A3%BC%EC%B0%A8-%EA%B3%BC%EC%A0%9C/ESAA_YB_Week2_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #3. 시본
# - 발전 과정 : 데이터를 적절한 시각화 정보로 가공해 데이터가 품고 있는 정제되고 본질적인 의미를 사용자나 일반 대중에게 전달하기 위해 발전
# -시각화 자체의 영역은 매우 방대 -> 전 영역을 익히기에는 오랜 시간이 필요할 수 있다.
# - EDA 혹은 데이터 분석을 수행하기 위한 압축된 방식의 시각화로 접근할 필요가 있다.

# %% [markdown]
# ## 1) 시각화를 위한 차트/그래프 유형
# `비지니스 분석을 위한 시각화`
# - 청중의 유형과 수준, 설득이 필요한 환경에 따라 적절하게 시각화 활용
# -  EX) 대도시별 평균 소득금액을 나타낼 때: 바 차트, 라인 차트, 파이 차트, 도넛 차트
#
# `통계 분석을 위한 시각화`
# - 설득이 필요한 다양한 환경에 따라 적절한 차트를 활용
# - 데이터 자체가 가지는 특성에 집중하는 경향
